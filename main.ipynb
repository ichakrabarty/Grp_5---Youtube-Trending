# %%
#importing dependencies
import pandas as pd
from datetime import datetime as dt

# %%
df= pd.read_csv('Datasources/US_youtube_trending_data.csv')
df
# Out:
#           video_id                                              title  \
# 0      3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1      M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2      J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3      kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4      VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...            ...                                                ...
# 68586  HOSWKHzsC1Q  Who Invited Her? | Niki and Gabi Jersey Shore EP1
# 68587  Oh5uLLNO1dI  #BTS #PermissiontoDance ✌✌ challenge only on @...
# 68588  kk-8DmwFkpA  Loki Episode 5 Marvel TOP 10 Breakdown Easter ...
# 68589  amdp4bN1RaE  LOKI 1x05: Every Easter Egg + RED SKULL  Conne...
# 68590  Ujv8bX_Xk94  Chris Broussard & Rob Parker - Rachel Nichols ...
#
#                 publishedAt                 channelId       channelTitle  \
# 0      2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg           Brawadis
# 1      2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A       Apex Legends
# 2      2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g      jacksepticeye
# 3      2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg                XXL
# 4      2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A           Mr. Kate
# ...                     ...                       ...                ...
# 68586  2021-07-07T23:48:34Z  UCuVHOs0H5hvAHGr8O4yIBNQ      Niki and Gabi
# 68587  2021-07-09T13:30:02Z  UCLkAepWjdylmXSltofFvsYQ          BANGTANTV
# 68588  2021-07-07T18:44:11Z  UCDiFRMQWpcp8_KD4vwIVicw  Emergency Awesome
# 68589  2021-07-08T00:05:04Z  UCgMJGv4cQl8-q71AyFeFmtg        ScreenCrush
# 68590  2021-07-07T18:00:18Z  UCWV-LeZ9dIBQyb8UuBGwdJw   Fox Sports Radio
#
#        categoryId         trending_date  \
# 0              22  2020-08-12T00:00:00Z
# 1              20  2020-08-12T00:00:00Z
# 2              24  2020-08-12T00:00:00Z
# 3              10  2020-08-12T00:00:00Z
# 4              26  2020-08-12T00:00:00Z
# ...           ...                   ...
# 68586          26  2021-07-14T00:00:00Z
# 68587          10  2021-07-14T00:00:00Z
# 68588          24  2021-07-14T00:00:00Z
# 68589           1  2021-07-14T00:00:00Z
# 68590          17  2021-07-14T00:00:00Z
#
#                                                     tags  view_count    likes  \
# 0      brawadis|prank|basketball|skits|ghost|funny vi...     1514614   156908
# 1      Apex Legends|Apex Legends characters|new Apex ...     2381688   146739
# 2      jacksepticeye|funny|funny meme|memes|jacksepti...     2038853   353787
# 3      xxl freshman|xxl freshmen|2020 xxl freshman|20...      496771    23251
# 4      The LaBrant Family|DIY|Interior Design|Makeove...     1123889    45802
# ...                                                  ...         ...      ...
# 68586  niki and gabi|niki and gabi reality show|niki ...      609321    34396
# 68587                                             [None]    14097267  2303028
# 68588  Loki|Loki Episode 5|Emergency Awesome|Loki Epi...     1377486    31213
# 68589  Loki easter eggs|Loki|loke premiere|loki scree...      927407    24264
# 68590  NBA|NFL|Basketball|Football|MLB|Baseball|Golf|...      289403     5596
#
#        dislikes  comment_count  \
# 0          5855          35313
# 1          2794          16549
# 2          2628          40221
# 3          1856           7647
# 4           964           2196
# ...         ...            ...
# 68586       509           1949
# 68587     33191          26116
# 68588       690           7379
# 68589       890           3010
# 68590       551           2949
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/3C66w5Z0ixs/default.jpg              False
# 1      https://i.ytimg.com/vi/M9Pmf9AB4Mo/default.jpg              False
# 2      https://i.ytimg.com/vi/J78aPJ3VyNs/default.jpg              False
# 3      https://i.ytimg.com/vi/kXLn3HkpjaA/default.jpg              False
# 4      https://i.ytimg.com/vi/VIUo6yapDbc/default.jpg              False
# ...                                               ...                ...
# 68586  https://i.ytimg.com/vi/HOSWKHzsC1Q/default.jpg              False
# 68587  https://i.ytimg.com/vi/Oh5uLLNO1dI/default.jpg              False
# 68588  https://i.ytimg.com/vi/kk-8DmwFkpA/default.jpg              False
# 68589  https://i.ytimg.com/vi/amdp4bN1RaE/default.jpg              False
# 68590  https://i.ytimg.com/vi/Ujv8bX_Xk94/default.jpg              False
#
#        ratings_disabled                                        description
# 0                 False  SUBSCRIBE to BRAWADIS ▶ http://bit.ly/Subscrib...
# 1                 False  While running her own modding shop, Ramya Pare...
# 2                 False  I left youtube for a month and this is what ha...
# 3                 False  Subscribe to XXL → http://bit.ly/subscribe-xxl...
# 4                 False  Transforming The LaBrant Family's empty white ...
# ...                 ...                                                ...
# 68586             False  EP1: “Who Invited Her? Niki and Gabi Jersey Sh...
# 68587             False                                                NaN
# 68588             False  Loki Episode 5 Journey Into Mystery. Ending Ex...
# 68589             False  Thanks to Keeps for sponsoring this video! Go ...
# 68590             False  THE ODD COUPLE - Chris Broussard & Rob Parker ...
#
# [68591 rows x 16 columns]

# %%
#leaving the columns we want to work with 
youtube_df= df[['video_id','title','publishedAt','channelId','channelTitle','categoryId','trending_date', 'tags','view_count','likes','dislikes' ]]

youtube_df
# Out:
#           video_id                                              title  \
# 0      3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1      M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2      J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3      kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4      VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...            ...                                                ...
# 68586  HOSWKHzsC1Q  Who Invited Her? | Niki and Gabi Jersey Shore EP1
# 68587  Oh5uLLNO1dI  #BTS #PermissiontoDance ✌✌ challenge only on @...
# 68588  kk-8DmwFkpA  Loki Episode 5 Marvel TOP 10 Breakdown Easter ...
# 68589  amdp4bN1RaE  LOKI 1x05: Every Easter Egg + RED SKULL  Conne...
# 68590  Ujv8bX_Xk94  Chris Broussard & Rob Parker - Rachel Nichols ...
#
#                 publishedAt                 channelId       channelTitle  \
# 0      2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg           Brawadis
# 1      2020-08-11T17:00:10Z  UC0ZV6M2THA81QT9hrVWJG3A       Apex Legends
# 2      2020-08-11T16:34:06Z  UCYzPXprvl5Y-Sf0g4vX-m6g      jacksepticeye
# 3      2020-08-11T16:38:55Z  UCbg_UMjlHJg_19SZckaKajg                XXL
# 4      2020-08-11T15:10:05Z  UCDVPcEbVLQgLZX0Rt6jo34A           Mr. Kate
# ...                     ...                       ...                ...
# 68586  2021-07-07T23:48:34Z  UCuVHOs0H5hvAHGr8O4yIBNQ      Niki and Gabi
# 68587  2021-07-09T13:30:02Z  UCLkAepWjdylmXSltofFvsYQ          BANGTANTV
# 68588  2021-07-07T18:44:11Z  UCDiFRMQWpcp8_KD4vwIVicw  Emergency Awesome
# 68589  2021-07-08T00:05:04Z  UCgMJGv4cQl8-q71AyFeFmtg        ScreenCrush
# 68590  2021-07-07T18:00:18Z  UCWV-LeZ9dIBQyb8UuBGwdJw   Fox Sports Radio
#
#        categoryId         trending_date  \
# 0              22  2020-08-12T00:00:00Z
# 1              20  2020-08-12T00:00:00Z
# 2              24  2020-08-12T00:00:00Z
# 3              10  2020-08-12T00:00:00Z
# 4              26  2020-08-12T00:00:00Z
# ...           ...                   ...
# 68586          26  2021-07-14T00:00:00Z
# 68587          10  2021-07-14T00:00:00Z
# 68588          24  2021-07-14T00:00:00Z
# 68589           1  2021-07-14T00:00:00Z
# 68590          17  2021-07-14T00:00:00Z
#
#                                                     tags  view_count    likes  \
# 0      brawadis|prank|basketball|skits|ghost|funny vi...     1514614   156908
# 1      Apex Legends|Apex Legends characters|new Apex ...     2381688   146739
# 2      jacksepticeye|funny|funny meme|memes|jacksepti...     2038853   353787
# 3      xxl freshman|xxl freshmen|2020 xxl freshman|20...      496771    23251
# 4      The LaBrant Family|DIY|Interior Design|Makeove...     1123889    45802
# ...                                                  ...         ...      ...
# 68586  niki and gabi|niki and gabi reality show|niki ...      609321    34396
# 68587                                             [None]    14097267  2303028
# 68588  Loki|Loki Episode 5|Emergency Awesome|Loki Epi...     1377486    31213
# 68589  Loki easter eggs|Loki|loke premiere|loki scree...      927407    24264
# 68590  NBA|NFL|Basketball|Football|MLB|Baseball|Golf|...      289403     5596
#
#        dislikes
# 0          5855
# 1          2794
# 2          2628
# 3          1856
# 4           964
# ...         ...
# 68586       509
# 68587     33191
# 68588       690
# 68589       890
# 68590       551
#
# [68591 rows x 11 columns]

# %%
youtube_df['publishedAt'].astype
# Out:
# <bound method NDFrame.astype of 0        2020-08-11T19:20:14Z
# 1        2020-08-11T17:00:10Z
# 2        2020-08-11T16:34:06Z
# 3        2020-08-11T16:38:55Z
# 4        2020-08-11T15:10:05Z
#                  ...
# 68586    2021-07-07T23:48:34Z
# 68587    2021-07-09T13:30:02Z
# 68588    2021-07-07T18:44:11Z
# 68589    2021-07-08T00:05:04Z
# 68590    2021-07-07T18:00:18Z
# Name: publishedAt, Length: 68591, dtype: object>

# %%
#transforming the datetime to new format
youtube_df['publishedAt'] = youtube_df['publishedAt'].str.split('T').str[0]
youtube_df['trending_date'] = youtube_df['trending_date'].str.split('T').str[0]
youtube_df.head()
# Out:
# <ipython-input-39-6089bcb2f34f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   youtube_df['publishedAt'] = youtube_df['publishedAt'].str.split('T').str[0]
# <ipython-input-39-6089bcb2f34f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   youtube_df['trending_date'] = youtube_df['trending_date'].str.split('T').str[0]
#       video_id                                              title publishedAt  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...  2020-08-11
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...  2020-08-11
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...  2020-08-11
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...  2020-08-11
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...  2020-08-11
#
#                   channelId   channelTitle  categoryId trending_date  \
# 0  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis          22    2020-08-12
# 1  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends          20    2020-08-12
# 2  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye          24    2020-08-12
# 3  UCbg_UMjlHJg_19SZckaKajg            XXL          10    2020-08-12
# 4  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate          26    2020-08-12
#
#                                                 tags  view_count   likes  \
# 0  brawadis|prank|basketball|skits|ghost|funny vi...     1514614  156908
# 1  Apex Legends|Apex Legends characters|new Apex ...     2381688  146739
# 2  jacksepticeye|funny|funny meme|memes|jacksepti...     2038853  353787
# 3  xxl freshman|xxl freshmen|2020 xxl freshman|20...      496771   23251
# 4  The LaBrant Family|DIY|Interior Design|Makeove...     1123889   45802
#
#    dislikes
# 0      5855
# 1      2794
# 2      2628
# 3      1856
# 4       964

# %%
# youtube_df['video_id','title','publishedAt','channelId','channelTitle','categoryId','trending_date', 'tags','view_count','likes','dislikes'] = youtube_df[['Video_ID','Title','Published_Date','Channel_ID','Channel_Title','Category_ID','Trending_Date', 'Tags','View_Count','Likes','Dislikes']]
# youtube_df
# youtube_df['video_id'] = youtube_df['Video_ID']
# youtube_df.columns['Video_ID','Title','Published_Date','Channel_ID','Channel_Title','Category_ID','Trending_Date', 'Tags','View_Count','Likes','Dislikes']
# youtube_df
dict = {'video_id': 'Video_id',
        'title': 'Title',
        'publishedAt': 'Published_date',
        'channelId': 'Chanel_id',
        'channelTitle': 'Channel_Title',
        'categoryId':'Category_id',
        'trending_date':"Trending_date" ,
        'tags':'Tags',
        'view_count':'View_count',
        'likes':'Likes',
        'dislikes':'Dislikes'
       }
# call rename () method
youtube_df.rename(columns=dict,
          inplace=True)
# print Data frame after rename columns
youtube_df
# Out:
# C:\Users\adamh\anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#           Video_id                                              Title  \
# 0      3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1      M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2      J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3      kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4      VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...            ...                                                ...
# 68586  HOSWKHzsC1Q  Who Invited Her? | Niki and Gabi Jersey Shore EP1
# 68587  Oh5uLLNO1dI  #BTS #PermissiontoDance ✌✌ challenge only on @...
# 68588  kk-8DmwFkpA  Loki Episode 5 Marvel TOP 10 Breakdown Easter ...
# 68589  amdp4bN1RaE  LOKI 1x05: Every Easter Egg + RED SKULL  Conne...
# 68590  Ujv8bX_Xk94  Chris Broussard & Rob Parker - Rachel Nichols ...
#
#       Published_date                 Chanel_id      Channel_Title  \
# 0         2020-08-11  UCvtRTOMP2TqYqu51xNrqAzg           Brawadis
# 1         2020-08-11  UC0ZV6M2THA81QT9hrVWJG3A       Apex Legends
# 2         2020-08-11  UCYzPXprvl5Y-Sf0g4vX-m6g      jacksepticeye
# 3         2020-08-11  UCbg_UMjlHJg_19SZckaKajg                XXL
# 4         2020-08-11  UCDVPcEbVLQgLZX0Rt6jo34A           Mr. Kate
# ...              ...                       ...                ...
# 68586     2021-07-07  UCuVHOs0H5hvAHGr8O4yIBNQ      Niki and Gabi
# 68587     2021-07-09  UCLkAepWjdylmXSltofFvsYQ          BANGTANTV
# 68588     2021-07-07  UCDiFRMQWpcp8_KD4vwIVicw  Emergency Awesome
# 68589     2021-07-08  UCgMJGv4cQl8-q71AyFeFmtg        ScreenCrush
# 68590     2021-07-07  UCWV-LeZ9dIBQyb8UuBGwdJw   Fox Sports Radio
#
#        Category_id Trending_date  \
# 0               22    2020-08-12
# 1               20    2020-08-12
# 2               24    2020-08-12
# 3               10    2020-08-12
# 4               26    2020-08-12
# ...            ...           ...
# 68586           26    2021-07-14
# 68587           10    2021-07-14
# 68588           24    2021-07-14
# 68589            1    2021-07-14
# 68590           17    2021-07-14
#
#                                                     Tags  View_count    Likes  \
# 0      brawadis|prank|basketball|skits|ghost|funny vi...     1514614   156908
# 1      Apex Legends|Apex Legends characters|new Apex ...     2381688   146739
# 2      jacksepticeye|funny|funny meme|memes|jacksepti...     2038853   353787
# 3      xxl freshman|xxl freshmen|2020 xxl freshman|20...      496771    23251
# 4      The LaBrant Family|DIY|Interior Design|Makeove...     1123889    45802
# ...                                                  ...         ...      ...
# 68586  niki and gabi|niki and gabi reality show|niki ...      609321    34396
# 68587                                             [None]    14097267  2303028
# 68588  Loki|Loki Episode 5|Emergency Awesome|Loki Epi...     1377486    31213
# 68589  Loki easter eggs|Loki|loke premiere|loki scree...      927407    24264
# 68590  NBA|NFL|Basketball|Football|MLB|Baseball|Golf|...      289403     5596
#
#        Dislikes
# 0          5855
# 1          2794
# 2          2628
# 3          1856
# 4           964
# ...         ...
# 68586       509
# 68587     33191
# 68588       690
# 68589       890
# 68590       551
#
# [68591 rows x 11 columns]

# %%
youtube_df_clean = youtube_df.drop('Tags', axis=1)
youtube_df_clean
# Out:
#           Video_id                                              Title  \
# 0      3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1      M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2      J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3      kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4      VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...            ...                                                ...
# 68586  HOSWKHzsC1Q  Who Invited Her? | Niki and Gabi Jersey Shore EP1
# 68587  Oh5uLLNO1dI  #BTS #PermissiontoDance ✌✌ challenge only on @...
# 68588  kk-8DmwFkpA  Loki Episode 5 Marvel TOP 10 Breakdown Easter ...
# 68589  amdp4bN1RaE  LOKI 1x05: Every Easter Egg + RED SKULL  Conne...
# 68590  Ujv8bX_Xk94  Chris Broussard & Rob Parker - Rachel Nichols ...
#
#       Published_date                 Chanel_id      Channel_Title  \
# 0         2020-08-11  UCvtRTOMP2TqYqu51xNrqAzg           Brawadis
# 1         2020-08-11  UC0ZV6M2THA81QT9hrVWJG3A       Apex Legends
# 2         2020-08-11  UCYzPXprvl5Y-Sf0g4vX-m6g      jacksepticeye
# 3         2020-08-11  UCbg_UMjlHJg_19SZckaKajg                XXL
# 4         2020-08-11  UCDVPcEbVLQgLZX0Rt6jo34A           Mr. Kate
# ...              ...                       ...                ...
# 68586     2021-07-07  UCuVHOs0H5hvAHGr8O4yIBNQ      Niki and Gabi
# 68587     2021-07-09  UCLkAepWjdylmXSltofFvsYQ          BANGTANTV
# 68588     2021-07-07  UCDiFRMQWpcp8_KD4vwIVicw  Emergency Awesome
# 68589     2021-07-08  UCgMJGv4cQl8-q71AyFeFmtg        ScreenCrush
# 68590     2021-07-07  UCWV-LeZ9dIBQyb8UuBGwdJw   Fox Sports Radio
#
#        Category_id Trending_date  View_count    Likes  Dislikes
# 0               22    2020-08-12     1514614   156908      5855
# 1               20    2020-08-12     2381688   146739      2794
# 2               24    2020-08-12     2038853   353787      2628
# 3               10    2020-08-12      496771    23251      1856
# 4               26    2020-08-12     1123889    45802       964
# ...            ...           ...         ...      ...       ...
# 68586           26    2021-07-14      609321    34396       509
# 68587           10    2021-07-14    14097267  2303028     33191
# 68588           24    2021-07-14     1377486    31213       690
# 68589            1    2021-07-14      927407    24264       890
# 68590           17    2021-07-14      289403     5596       551
#
# [68591 rows x 10 columns]
