# %%
#importing dependencies
import pandas as pd
from datetime import datetime as dt

# %%
df= pd.read_csv('Datasources/US_youtube_trending_data.csv')
df
# Out:
#           video_id                                              title  \
# 0      3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1      M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2      J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3      kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4      VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...            ...                                                ...
# 69186  XeuXShFIgyc       Why Millions Buy Harley-Davidson Motorcycles
# 69187  CLUNE8OVvEw  CHANNEL UPDATE: The UNCERTAIN Future of the Be...
# 69188  NLffKOOyxwI                                           hospital
# 69189  r16Rz2J5IZo              If Water Fights Were Like Video Games
# 69190  KISlIJDOMJU                   HIDE & SEEK ON KSI’s PRIVATE JET
#
#                 publishedAt                 channelId  \
# 0      2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg
# ...

# %%
#leaving the columns we want to work with 
youtube_df= df[['video_id','title','publishedAt','channelId','channelTitle','categoryId','trending_date', 'tags','view_count','likes','dislikes' ]]

youtube_df
# Out:
#           video_id                                              title  \
# 0      3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1      M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2      J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3      kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4      VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...            ...                                                ...
# 69186  XeuXShFIgyc       Why Millions Buy Harley-Davidson Motorcycles
# 69187  CLUNE8OVvEw  CHANNEL UPDATE: The UNCERTAIN Future of the Be...
# 69188  NLffKOOyxwI                                           hospital
# 69189  r16Rz2J5IZo              If Water Fights Were Like Video Games
# 69190  KISlIJDOMJU                   HIDE & SEEK ON KSI’s PRIVATE JET
#
#                 publishedAt                 channelId  \
# 0      2020-08-11T19:20:14Z  UCvtRTOMP2TqYqu51xNrqAzg
# ...

# %%
youtube_df['publishedAt'].astype
# Out:
# <bound method NDFrame.astype of 0        2020-08-11T19:20:14Z
# 1        2020-08-11T17:00:10Z
# 2        2020-08-11T16:34:06Z
# 3        2020-08-11T16:38:55Z
# 4        2020-08-11T15:10:05Z
#                  ...
# 69186    2021-07-11T15:00:13Z
# 69187    2021-07-11T12:27:01Z
# 69188    2021-07-10T14:02:33Z
# 69189    2021-07-09T15:00:11Z
# 69190    2021-07-10T18:00:06Z
# Name: publishedAt, Length: 69191, dtype: object>

# %%
#transforming the datetime to new format
youtube_df['publishedAt'] = youtube_df['publishedAt'].str.split('T').str[0]
youtube_df['trending_date'] = youtube_df['trending_date'].str.split('T').str[0]
youtube_df.head()
# Out:
# <ipython-input-5-6089bcb2f34f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   youtube_df['publishedAt'] = youtube_df['publishedAt'].str.split('T').str[0]
# <ipython-input-5-6089bcb2f34f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   youtube_df['trending_date'] = youtube_df['trending_date'].str.split('T').str[0]
#       video_id                                              title publishedAt  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...  2020-08-11
# ...

# %%
dict = {'video_id': 'Video_id',
        'title': 'Title',
        'publishedAt': 'Published_date',
        'channelId': 'Chanel_id',
        'channelTitle': 'Channel_Title',
        'categoryId':'Category_id',
        'trending_date':"Trending_date" ,
        'tags':'Tags', 
        'view_count':'View_count', 
        'likes':'Likes',
        'dislikes':'Dislikes'            
                
        
       }
  
# call rename () method
youtube_df.rename(columns=dict,
          inplace=True)
  
# print Data frame after rename columns
youtube_df
# Out:
# C:\Users\squiros\Anaconda3\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#           Video_id                                              Title  \
# 0      3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1      M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2      J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3      kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4      VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...            ...                                                ...
# 69186  XeuXShFIgyc       Why Millions Buy Harley-Davidson Motorcycles
# 69187  CLUNE8OVvEw  CHANNEL UPDATE: The UNCERTAIN Future of the Be...
# ...

# %%
youtube_df.drop('Tags', axis=1, inplace=True)
youtube_df
# Out:
# C:\Users\squiros\Anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#           Video_id                                              Title  \
# 0      3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1      M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2      J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3      kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4      VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
# ...            ...                                                ...
# 69186  XeuXShFIgyc       Why Millions Buy Harley-Davidson Motorcycles
# 69187  CLUNE8OVvEw  CHANNEL UPDATE: The UNCERTAIN Future of the Be...
# ...

# %%
import json

# %%
with open('Datasources/US_category_id.json') as f:
    data= json.load(f)

# %%
data
# Out:
# {'kind': 'youtube#videoCategoryListResponse',
#  'etag': 'HIrK3n45Uw2IYz9_U2-gK1OsXvo',
#  'items': [{'kind': 'youtube#videoCategory',
#    'etag': 'IfWa37JGcqZs-jZeAyFGkbeh6bc',
#    'id': '1',
#    'snippet': {'title': 'Film & Animation',
#     'assignable': True,
#     'channelId': 'UCBR8-60-B28hp2BmDPdntcQ'}},
#   {'kind': 'youtube#videoCategory',
#    'etag': '5XGylIs7zkjHh5940dsT5862m1Y',
#    'id': '2',
#    'snippet': {'title': 'Autos & Vehicles',
#     'assignable': True,
#     'channelId': 'UCBR8-60-B28hp2BmDPdntcQ'}},
#   {'kind': 'youtube#videoCategory',
#    'etag': 'HCjFMARbBeWjpm6PDfReCOMOZGA',
#    'id': '10',
#    'snippet': {'title': 'Music',
#     'assignable': True,
#     'channelId': 'UCBR8-60-B28hp2BmDPdntcQ'}},
#   {'kind': 'youtube#videoCategory',
#    'etag': 'ra8H7xyAfmE2FewsDabE3TUSq10',
#    'id': '15',
#    'snippet': {'title': 'Pets & Animals',
#     'assignable': True,
#     'channelId': 'UCBR8-60-B28hp2BmDPdntcQ'}},
# ...

# %%
df= pd.DataFrame(data['items'])
df_merge = pd.concat([df,pd.json_normalize(df.snippet)], axis=1)
df_merge
# Out:
#                      kind                         etag  id  \
# 0   youtube#videoCategory  IfWa37JGcqZs-jZeAyFGkbeh6bc   1
# 1   youtube#videoCategory  5XGylIs7zkjHh5940dsT5862m1Y   2
# 2   youtube#videoCategory  HCjFMARbBeWjpm6PDfReCOMOZGA  10
# 3   youtube#videoCategory  ra8H7xyAfmE2FewsDabE3TUSq10  15
# 4   youtube#videoCategory  7mqChSJogdF3hSIL-88BfDE-W8M  17
# 5   youtube#videoCategory  0Z6uGkj97NgjD-X3pkA-nL18Hqk  18
# 6   youtube#videoCategory  K_-7stg0kIU7eUBOPUa6j5fqIMQ  19
# 7   youtube#videoCategory  I3IL9xGIM3MsULlqR4tvCsEKv98  20
# 8   youtube#videoCategory  D1W6tq5mMMCV0wtNxf9A6g9wWjU  21
# 9   youtube#videoCategory  QMEBz6mxVdklVaq8JwesPEw_4nI  22
# 10  youtube#videoCategory  v2n6q4JttoL4uUbazrcxNQRGPZk  23
# 11  youtube#videoCategory  Qi1csjh-POReitZEbR7CUw7dmao  24
# 12  youtube#videoCategory  IbGXblQi8v_nOsXjirhul1NVcH8  25
# 13  youtube#videoCategory  gYzt8dB8mlod-84ipMtjynYe9xU  26
# 14  youtube#videoCategory  hHUhloYhyMMqVkQ4LH9sr3aRQoU  27
# ...

# %%
df_test = pd.json_normalize(data['items'])
df_test
# Out:
#                      kind                         etag  id  \
# 0   youtube#videoCategory  IfWa37JGcqZs-jZeAyFGkbeh6bc   1
# 1   youtube#videoCategory  5XGylIs7zkjHh5940dsT5862m1Y   2
# 2   youtube#videoCategory  HCjFMARbBeWjpm6PDfReCOMOZGA  10
# 3   youtube#videoCategory  ra8H7xyAfmE2FewsDabE3TUSq10  15
# 4   youtube#videoCategory  7mqChSJogdF3hSIL-88BfDE-W8M  17
# 5   youtube#videoCategory  0Z6uGkj97NgjD-X3pkA-nL18Hqk  18
# 6   youtube#videoCategory  K_-7stg0kIU7eUBOPUa6j5fqIMQ  19
# 7   youtube#videoCategory  I3IL9xGIM3MsULlqR4tvCsEKv98  20
# 8   youtube#videoCategory  D1W6tq5mMMCV0wtNxf9A6g9wWjU  21
# 9   youtube#videoCategory  QMEBz6mxVdklVaq8JwesPEw_4nI  22
# 10  youtube#videoCategory  v2n6q4JttoL4uUbazrcxNQRGPZk  23
# 11  youtube#videoCategory  Qi1csjh-POReitZEbR7CUw7dmao  24
# 12  youtube#videoCategory  IbGXblQi8v_nOsXjirhul1NVcH8  25
# 13  youtube#videoCategory  gYzt8dB8mlod-84ipMtjynYe9xU  26
# 14  youtube#videoCategory  hHUhloYhyMMqVkQ4LH9sr3aRQoU  27
# ...

# %%
categories_df = df_test[['id','snippet.title']].rename(columns={'id':'categoryid','snippet.title': 'categorytitle'})
categories_df
# Out:
#    categoryid          categorytitle
# 0           1       Film & Animation
# 1           2       Autos & Vehicles
# 2          10                  Music
# 3          15         Pets & Animals
# 4          17                 Sports
# 5          18           Short Movies
# 6          19        Travel & Events
# 7          20                 Gaming
# 8          21          Videoblogging
# 9          22         People & Blogs
# 10         23                 Comedy
# 11         24          Entertainment
# 12         25        News & Politics
# 13         26          Howto & Style
# 14         27              Education
# 15         28   Science & Technology
# 16         29  Nonprofits & Activism
# 17         30                 Movies
# 18         31        Anime/Animation
# 19         32       Action/Adventure
# 20         33               Classics
# 21         34                 Comedy
# 22         35            Documentary
# 23         36                  Drama
# ...

# %%
channel_df = youtube_df[['Channel_Title']].drop_duplicates(ignore_index=True)
channel_df
# Out:
#            Channel_Title
# 0               Brawadis
# 1           Apex Legends
# 2          jacksepticeye
# 3                    XXL
# 4               Mr. Kate
# ...                  ...
# 3619                Buur
# 3620         shakiraVEVO
# 3621           FUNK FLEX
# 3622              Chewkz
# 3623  Quadeca Exclusives
#
# [3624 rows x 1 columns]

# %%
#creating the channel table
youtube_df['Chanel_id'] = youtube_df.apply(lambda x:channel_df[(channel_df.Channel_Title == x.Channel_Title)].index[0], axis=1)
youtube_df.head()
# Out:
# <ipython-input-31-6073d8d65233>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   youtube_df['Chanel_id'] = youtube_df.apply(lambda x:channel_df[(channel_df.Channel_Title == x.Channel_Title)].index[0], axis=1)
#       Video_id                                              Title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#   Published_date  Chanel_id  Channel_Title  Category_id Trending_date  \
# ...

# %%
[f"{x}: {youtube_df[x].nunique()}" for x in youtube_df.columns]
#youtube_df.loc[~youtube_df[["Video_id","Channel_Title","Published_date", "Category_id"]].duplicated()]
#any(youtube_df[["Trending_date","Video_id"]].duplicated())
# Out:
# ['Video_id: 11603',
#  'Title: 11851',
#  'Published_date: 347',
#  'Chanel_id: 3624',
#  'Channel_Title: 3624',
#  'Category_id: 15',
#  'Trending_date: 326',
#  'View_count: 68282',
#  'Likes: 57296',
#  'Dislikes: 11672',
#  'title_id: 11851']

# %%
title_df = youtube_df[['Title']].drop_duplicates(ignore_index=True).rename(columns = {'index' : 'titleid','Title':'title'})
# Out:
#                                                    title
# 0                     I ASKED HER TO BE MY GIRLFRIEND...
# 1      Apex Legends | Stories from the Outlands – “Th...
# 2      I left youtube for a month and THIS is what ha...
# 3      XXL 2020 Freshman Class Revealed - Official An...
# 4      Ultimate DIY Home Movie Theater for The LaBran...
# ...                                                  ...
# 11846                       This is Starting to Get Ugly
# 11847      Ice Cream - You Suck at Cooking (episode 130)
# 11848                            Trope Talk: All A Dream
# 11849  Shattering a Wine Glass with Sound at 187,500F...
# 11850                Would YOU Quit School For $100,000?
#
# [11851 rows x 1 columns]

# %%
# youtube_df['title_id'] = youtube_df.apply(lambda x:title_df[(title_df.title == x.Title)].index[0], axis=1)
# youtube_df.head()
# Out:
# <ipython-input-24-3f143cb681f3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   youtube_df['title_id'] = youtube_df.apply(lambda x:title_df[(title_df.title == x.Title)].index[0], axis=1)
#       Video_id                                              Title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#   Published_date                 Chanel_id  Channel_Title  Category_id  \
# ...

# %%
youtube_df.Title.nunique()
# Out:
# 11851

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5432/youtube_db')
connection = engine.connect()

# %%
engine.table_names()
# Out:
# ['channel', 'videos', 'category', 'titles']

# %%
categories_df.to_sql(name='category', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# UniqueViolation: duplicate key value violates unique constraint "category_pkey"
# DETAIL:  Key (categoryid)=(1) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
channel_df.to_sql(name='channel', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# UniqueViolation: duplicate key value violates unique constraint "channel_pkey"
# DETAIL:  Key (channelid)=(UCi5iiEyLwSLvlqnMi02u5gQ) already exists.
#
#
# The above exception was the direct cause of the following exception:
# ...

# %%
title_df.to_sql(name='titles', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# UniqueViolation: duplicate key value violates unique constraint "titles_pkey"
# DETAIL:  Key (titleid)=(0) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
pd.read_sql_query('select * from category' , con = engine).head()
# Out:
#    categoryid     categorytitle
# 0           1  Film & Animation
# 1           2  Autos & Vehicles
# 2          10             Music
# 3          15    Pets & Animals
# 4          17            Sports

# %%
pd.read_sql_query('select * from titles' , con = engine).head()
# Out:
#    titleid                                              title
# 0        0                 I ASKED HER TO BE MY GIRLFRIEND...
# 1        1  Apex Legends | Stories from the Outlands – “Th...
# 2        2  I left youtube for a month and THIS is what ha...
# 3        3  XXL 2020 Freshman Class Revealed - Official An...
# 4        4  Ultimate DIY Home Movie Theater for The LaBran...

# %%
pd.read_sql_query('select * from channel' , con = engine).head()
# Out:
# Empty DataFrame
# Columns: [channelid, channeltitle]
# Index: []
